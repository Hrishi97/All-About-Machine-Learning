# %% [markdown]
# ## Evaluating Regression Models -

# %% [markdown]
# ### 1. R-Squared -
#
# ### It is a measurement that tells you to what extent the proportion of the variance of the dependent variable is explained by the variance in the independent variables.
#
# ### While the coefficients estimates trends, R-Squared represents the scatter around the line of best fit.
#
# ### ![image.png](attachment:image.png)

# %% [markdown]
# ### The equation for R² is as follows:
#
# ![image.png](attachment:image.png)
#
# ### The Explained Variation is equal to the sum of squared residuals while the total variation is equal to the total sum of squared.
#
# ![image-2.png](attachment:image-2.png)
#
# ### Code -
#
# #### from sklearn.metrics import r2_score
# #### sklearn.metrics.r2_score(y_true, y_pred)

# %% [markdown]
# ![R-Squared.png](attachment:R-Squared.png)

# %% [markdown]
# ### 2. Adjusted R-Squared - This method takes into account the number of independent variables used for predicting the target variables. In doing so, we can tell whether adding a new variable increases the model fit.
#
# ### Ways to find out the Adjusted R-Squared -
#
# #### a. Manual Calculation:
#
# 1. n represents the number of data points in our dataset
# 2. k represents the number of independent variables, and
# 3. R represents the R-squared values determined by the model.
#
# ![image.png](attachment:image.png)
#
# #### b. statsmodel.api
#
# ##### import statsmodels.api as sm
# ##### from statsmodels.sandbox.regression.predstd import wls_prediction_std
# ##### model1=sm.OLS(y_train,x_train)
# ##### result=model1.fit()
# ##### print(result.summary())

# %% [markdown]
# ![Adjusted%20R-Squared.png](attachment:Adjusted%20R-Squared.png)

# %% [markdown]
# ### 3. Mean Absolute Error -
#
# ### The absolute error is the difference between the predicted values and the actual values. Thus, the mean absolute error is the average of the absolute error.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### from sklearn.metrics import mean_absolute_error
# #### mean_absolute_error(y_test,y_pred)

# %% [markdown]
# ### 4. Mean Squared Error -
#
# ### The mean squared error or MSE is similar to the MAE, except you take the average of the squared differences between the predicted values and the actual values.
#
# ### Because the differences are squared, larger errors are weighted more highly, and so this should be used over the MAE when you want to minimize large errors. Below is the equation for MSE, as well as the code.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### from sklearn.metrics import mean_squared_error
# #### mean_squared_error(y_test,y_pred)

# %% [markdown]
# ### 3. Mean Absolute Error -
#
# ### The absolute error is the difference between the predicted values and the actual values. Thus, the mean absolute error is the average of the absolute error.
#
# ![image.png](attachment:image.png)
#
# #### from sklearn.metrics import mean_absolute_error
# #### mean_absolute_error(y_test,y_pred)

# %% [markdown]
# ### 4. Mean Squared Error -
#
# ### The mean squared error or MSE is similar to the MAE, except you take the average of the squared differences between the predicted values and the actual values.
#
# ### Because the differences are squared, larger errors are weighted more highly, and so this should be used over the MAE when you want to minimize large errors. Below is the equation for MSE, as well as the code.
#
# ![image.png](attachment:image.png)
#
# #### from sklearn.metrics import mean_squared_error
# #### mean_squared_error(y_test,y_pred)

# %% [markdown]
# ## Evaluating Classification Models -
