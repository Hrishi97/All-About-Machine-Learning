# %% [markdown]
# Applications of Machine Learning
#
# 1. Facial Recognition
# 2. Virtual Reality Headsets
# 3. Voice Recognition
# 4. Robotics
#     5. Recommendation Systems used by Amazon, Netflix, etc

# %% [markdown]
# Difference between Machine Learning, Deep Learning and Artifical Intelligence
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Artifical Intelligence -
#
# Science that empowers computers to mimic human intelligence such as decision making, visual perception, text processing, etc.
#
# Ai is broader field that contains several subfield such as machine learning, computer vision

# %% [markdown]
# 2. Machine Learning -
#
# It is a subfield of Artifical Intelligence that enables machine to improve at a given task with experience. All machine learning techniques are classified as AI ones. However, not all AI count as ML since not all algorithms learn from experience.
#
#     a. Supervised Learning - Training algorithms using labeled input/output data. (Classification/Clustering)
#     b. Unsupervised Learning - Training algorithms using no labeled data. It attempts at discovering hidden patterns on its own. (Clustering)
#     c. Reinforcement Learning - Algorithms take actions to maximize cumulative rewards. This type of learning involves an external agent.

# %% [markdown]
# 3. Deep Learning -
#
# It is a specialized field in ML that relies on training deep ANNs (Artifical Neural Networks) using a large datasets such as images and texts.
#
# ANNs are information processing model inspired by human brain. ANNs works by connecting multiple artificial neurons in a multi-layered fashion. The more hidden layers added to the network, the deeper the network gets.
#
#
# ![image.png](attachment:image.png)
